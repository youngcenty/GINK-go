# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import scipy.stats as stats
import statsmodels.api as sm
from scipy.stats import mannwhitneyu
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
import warnings
import re
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("genes/combined-gene-on-off.csv")
df = df[df["celltype"] == "HBEC"]
d1 = pd.read_csv(f"~/projects/transcriptome_4D/data/gene_property/HBEC_ATAC_tss.tab", header=None, sep='\t',
                          names=["gene", "size", "covered", "total", "mean0", "HBEC_ATAC_tss"])
df = pd.merge(d1[["gene", "HBEC_ATAC_tss"]], df, on="gene")
df[df["HBEC_ATAC_tss"] <= 5]
# Out:
#     gene         off-period  on-period  off-mean   on-mean  K-off-rate  \
# 0  LUZP1  [213, 55, 11, 40]  [7, 7, 2]     79.75  5.333333      0.1875
#
#    K-on-rate  off-median  on-median  off-period-counts  on-period-counts  \
# 0   0.012539        47.5        7.0                  4                 3
#
#      TATA_group    inr_group chr_x strand_x         TSS             geneID  \
# 0  without_TATA  without_inr  chr1        -  23178121.0  ENSG00000169641.9
#
#    TATA +  YY1 +   SP +  SP -  ETS +  ETS -  NFY +  NFY -  CREB +  CREB -  \
# 0   0.009  0.011 -0.126 -0.16 -0.028  -0.07  0.045  0.065   0.498   0.435
#
#    NRF1 +  NRF1 -  ZNF143 +  ZNF143 -  U1 snRNP + chr_y       start  \
# 0  -0.004   0.001    -0.001    -0.067       0.186  chr1  23084023.0
#
#           end strand_y          gene_id  transcript_id  distance2tss celltype  \
# 0  23177808.0        -  ENSG00000169641            NaN         313.0     HBEC
#
#     cluster gene_type comment
# 0  cluster0    simple     NaN

# %%
df = pd.read_csv("genes/combined-gene-on-off.csv")
df = df[df["celltype"] == "H9D0"]
d1 = pd.read_csv(f"~/projects/transcriptome_4D/data/gene_property/ESC_D0_ATAC_tss.tab", header=None, sep='\t',
                          names=["gene", "size", "covered", "total", "mean0", "ATAC_tss"])
df = pd.merge(d1[["gene", "ATAC_tss"]], df, on="gene")
df[df["ATAC_tss"] <= 5]
# Out:
#      gene  ATAC_tss                                         off-period  \
# 5  ADGRF1   2.13549                                   [10, 16, 25, 31]
# 8   EEF1D   2.02574  [68, 15, 100, 9, 12, 31, 19, 3, 3, 95, 36, 5, ...
# 9  SEC16A   1.00314  [82, 71, 6, 16, 5, 23, 22, 5, 4, 2, 3, 15, 36,...
#
#                                            on-period   off-mean    on-mean  \
# 5                                [50, 7, 31, 84, 31]  20.500000  40.600000
# 8  [40, 57, 28, 6, 16, 33, 29, 16, 54, 18, 26, 42...  17.040816  19.775510
# 9  [5, 1, 15, 7, 8, 3, 3, 1, 3, 1, 15, 9, 4, 28, ...  21.918216  15.230469
#
#    K-off-rate  K-on-rate  off-median  on-median  off-period-counts  \
# 5    0.024631   0.048780        20.5       31.0                  4
# 8    0.050568   0.058683         8.0       16.0                 49
# 9    0.065658   0.045624        14.0       10.5                269
#
#    on-period-counts    TATA_group inr_group chr_x strand_x          TSS  \
# ...

# %%
df = pd.read_csv("genes/combined-gene-on-off.csv")
df = df[df["celltype"] == "H9D3"]
d1 = pd.read_csv(f"~/projects/transcriptome_4D/data/gene_property/ESC_D3_ATAC_tss.tab", header=None, sep='\t',
                          names=["gene", "size", "covered", "total", "mean0", "ATAC_tss"])
df = pd.merge(d1[["gene", "ATAC_tss"]], df, on="gene")
df[df["ATAC_tss"] <= 6]
# Out:
#       gene  ATAC_tss                                         off-period  \
# 2    DISC1  0.955336                                   [45, 71, 66, 20]
# 11   EEF1D  1.577110  [3, 14, 11, 17, 90, 3, 48, 3, 5, 2, 7, 21, 15,...
# 12  SEC16A  0.770206  [5, 9, 82, 29, 5, 45, 29, 5, 13, 20, 4, 10, 10...
# 14   CELF1  0.937525          [9, 3, 5, 3, 4, 3, 3, 8, 4, 6, 7, 22, 36]
# 17  HNRNPC  1.930910  [4, 9, 5, 9, 7, 99, 9, 5, 5, 3, 10, 8, 23, 7, ...
#
#                                             on-period   off-mean    on-mean  \
# 2                                          [2, 10, 7]  50.500000   6.333333
# 11  [40, 27, 10, 15, 3, 16, 3, 18, 28, 20, 12, 13,...  22.300000  18.588235
# 12  [3, 11, 7, 17, 15, 6, 12, 4, 7, 32, 33, 6, 13,...  18.414414  12.864486
# 14          [8, 21, 2, 16, 12, 26, 20, 3, 34, 78, 27]   8.692308  22.454545
# 17  [37, 21, 36, 19, 164, 2, 3, 22, 1, 5, 17, 81, ...  11.209677  23.718750
#
#     K-off-rate  K-on-rate  off-median  on-median  off-period-counts  \
# ...
